# %% [markdown]
# <a href="https://colab.research.google.com/github/0xs1d/pwskills/blob/main/Useful_NLP_Libraries_and_Networks_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Useful NLP Libraries & Networks – Assignment
#
# **Assignment Code:** DS-AG-029

# %% [markdown]
# ## Question 1: Compare and contrast NLTK and spaCy in terms of features, ease of use, and performance.
#
# | Feature | NLTK | spaCy |
# |---|---|---|
# | Purpose | Educational and research-focused | Industrial and production-focused |
# | Ease of Use | Beginner-friendly | Developer-friendly |
# | Speed | Slower | Faster |
# | Built-in Models | Limited | Powerful pre-trained models |
# | Use Cases | Teaching and experimentation | Real-time NLP applications |
#
# NLTK is widely used for learning NLP concepts, while spaCy is preferred in industry due to its speed and optimized pipelines.

# %% [markdown]
# ## Question 2: What is TextBlob and how does it simplify common NLP tasks like sentiment analysis and translation?
#
# TextBlob is a Python library built on top of NLTK and Pattern that simplifies common NLP tasks.
#
# ### Features of TextBlob:
# - Sentiment analysis
# - Translation
# - Tokenization
# - POS tagging
# - Noun phrase extraction
#
# ### Advantages:
# - Simple syntax
# - Beginner-friendly
# - Quick implementation of NLP tasks
#
# Example:
# ```python
# from textblob import TextBlob
# blob = TextBlob("I love NLP")
# print(blob.sentiment)
# ```

# %% [markdown]
# ## Question 3: Explain the role of Stanford NLP in academic and industry NLP projects.
#
# Stanford NLP provides advanced NLP tools and models for linguistic analysis.
#
# ### Role in Academia:
# - Used in NLP research
# - Supports syntax parsing and semantic analysis
# - Useful for experimentation and benchmarking
#
# ### Role in Industry:
# - Information extraction
# - Named entity recognition
# - Sentiment analysis
# - Chatbot systems
#
# Stanford NLP is known for high-quality language processing tools and multilingual support.

# %% [markdown]
# ## Question 4: Describe the architecture and functioning of a Recurrent Neural Network (RNN).
#
# A Recurrent Neural Network (RNN) is designed for sequential data such as text and speech.
#
# ### Architecture:
# - Input layer
# - Hidden recurrent layer
# - Output layer
#
# ### Functioning:
# RNNs maintain a hidden state that captures information from previous time steps. This makes them suitable for sequence prediction tasks.
#
# ### Applications:
# - Language modeling
# - Speech recognition
# - Machine translation

# %% [markdown]
# ## Question 5: What is the key difference between LSTM and GRU networks in NLP applications?
#
# | Feature | LSTM | GRU |
# |---|---|---|
# | Gates | Input, Forget, Output | Update and Reset |
# | Complexity | More complex | Simpler |
# | Training Speed | Slower | Faster |
# | Performance | Better for long sequences | Efficient for smaller datasets |
#
# LSTM networks are more powerful for capturing long-term dependencies, while GRUs are computationally efficient.

# %% [markdown]
# ## Question 6: Sentiment Analysis using TextBlob

# %%
from textblob import TextBlob

text = '''
I had a great experience using the new mobile banking app.
The interface is intuitive, and customer support was quick to resolve my issue.
However, the app did crash once during a transaction, which was frustrating.
'''

blob = TextBlob(text)

print("Polarity:", blob.sentiment.polarity)
print("Subjectivity:", blob.sentiment.subjectivity)
# Out:
# Polarity: 0.21742424242424244
# Subjectivity: 0.6511363636363636

# %% [markdown]
# ## Question 7: Tokenization and Frequency Distribution using NLTK

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

nltk.download('punkt')
nltk.download('punkt_tab')

paragraph = '''
Natural Language Processing (NLP) is a fascinating field that combines linguistics,
computer science, and artificial intelligence. It enables machines to understand,
interpret, and generate human language.
'''

tokens = word_tokenize(paragraph)

print("Tokens:")
print(tokens)

freq_dist = FreqDist(tokens)

print("\nMost Common Tokens:")
print(freq_dist.most_common(10))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# Tokens:
# ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'fascinating', 'field', 'that', 'combines', 'linguistics', ',', 'computer', 'science', ',', 'and', 'artificial', 'intelligence', '.', 'It', 'enables', 'machines', 'to', 'understand', ',', 'interpret', ',', 'and', 'generate', 'human', 'language', '.']
#
# Most Common Tokens:
# [(',', 4), ('and', 2), ('.', 2), ('Natural', 1), ('Language', 1), ('Processing', 1), ('(', 1), ('NLP', 1), (')', 1), ('is', 1)]
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %% [markdown]
# ## Question 8: Basic LSTM Model in Keras

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
import numpy as np

texts = [
    "I love this project",
    "This is an amazing experience",
    "I hate waiting in line",
    "This is the worst service",
    "Absolutely fantastic!"
]

labels = [1, 1, 0, 0, 1]

tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

sequences = tokenizer.texts_to_sequences(texts)

padded = pad_sequences(sequences, padding='post')

X = np.array(padded)
y = np.array(labels)

model = Sequential([
    Embedding(input_dim=50, output_dim=8, input_length=X.shape[1]),
    LSTM(16),
    Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()

model.fit(X, y, epochs=10, verbose=1)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# ...

# %% [markdown]
# ## Question 9: spaCy NLP Pipeline

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

text = '''
Homi Jehangir Bhaba was an Indian nuclear physicist who played a key role
in the development of India’s atomic energy program.
'''

doc = nlp(text)

print("Tokens and Lemmas:")

for token in doc:
    print(token.text, "->", token.lemma_)

print("\nNamed Entities:")

for ent in doc.ents:
    print(ent.text, ":", ent.label_)
# Out:
# Tokens and Lemmas:
#
#  ->
#
# Homi -> Homi
# Jehangir -> Jehangir
# Bhaba -> Bhaba
# was -> be
# an -> an
# Indian -> indian
# nuclear -> nuclear
# physicist -> physicist
# who -> who
# played -> play
# a -> a
# key -> key
# role -> role
#
#  ->
#
# in -> in
# the -> the
# development -> development
# of -> of
# India -> India
# ’s -> ’s
# atomic -> atomic
# energy -> energy
# program -> program
# . -> .
#
#  ->
#
#
# Named Entities:
# Indian : NORP
# India : GPE

# %% [markdown]
# ## Question 10: Chatbot for a Mental Health Platform
#
# ### Architecture:
# - User input
# - Text preprocessing
# - LSTM/GRU model
# - Intent detection
# - Response generation
#
# ### NLP Libraries:
# - spaCy for tokenization, lemmatization, and entity recognition
# - Stanford NLP for deeper linguistic analysis
#
# ### Data Preprocessing Pipeline:
# 1. Lowercasing
# 2. Tokenization
# 3. Stopword removal
# 4. Lemmatization
# 5. Sequence padding
#
# ### Ethical Considerations:
# - Data privacy
# - Avoiding harmful responses
# - Human escalation for crisis situations
# - Bias reduction in training data
#
# ### Deployment:
# Deploy the chatbot using APIs and continuously monitor user interactions for improvement.

# %%
sample_text = "I feel anxious and stressed lately."

print("Sample User Input:")
print(sample_text)

print("\nPotential Chatbot Response:")
print("I'm sorry to hear that. Would you like some relaxation exercises or resources?")
# Out:
# Sample User Input:
# I feel anxious and stressed lately.
#
# Potential Chatbot Response:
# I'm sorry to hear that. Would you like some relaxation exercises or resources?
